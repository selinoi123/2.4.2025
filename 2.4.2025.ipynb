# %%
import numpy as np
from IPython.display import display
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Selin/Desktop/sport_athletes.csv")
df_copy = df.copy()
df_copy1 = df.copy()

# %%
df_copy
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...

# %%
#Question num 1
result = df_copy.groupby('Sport Type').agg({
    'Weight(kg)' : 'min',
    'Height(cm)' : 'max',
    'Wins' : 'max' 
}).reset_index().sort_values(by = 'Sport Type')
display(result)
# Out:
#         Sport Type  Weight(kg)  Height(cm)  Wins
# 0       Basketball          96         216     3
# 1          Cycling          68         186     5
# 2       Gymnastics          45         160     5
# 3           Soccer          57         187     3
# 4         Swimming          58         200     5
# 5           Tennis          70         188     4
# 6  Track and Field          57         195     6

# %%
#Question num 1 a b c
result = result.rename(columns={
    'Weight(kg)': 'weight_min',
    'Height(cm)': 'height_max',
    'Wins': 'wins_max'
}).sort_values(by = 'Sport Type')

display(result)
# Out:
#         Sport Type  weight_min  height_max  wins_max
# 0       Basketball          96         216         3
# 1          Cycling          68         186         5
# 2       Gymnastics          45         160         5
# 3           Soccer          57         187         3
# 4         Swimming          58         200         5
# 5           Tennis          70         188         4
# 6  Track and Field          57         195         6

# %%
#Question num 2
df_sorted = df_copy.sort_values(by = ['Sport Type', 'Height(cm)'], ascending=[True, False])
top2 = df_sorted.groupby('Sport Type').head(2).reset_index()
display(top2[['Sport Type','Height(cm)', 'Athlete Name']])
# Out:
#          Sport Type  Height(cm)       Athlete Name
# 0        Basketball         216   Shaquille O'Neal
# 1        Basketball         208       Kevin Durant
# 2           Cycling         186      Primoz Roglic
# 3           Cycling         184      Tadej Pogacar
# 4        Gymnastics         160        Aly Raisman
# 5        Gymnastics         157      Shawn Johnson
# 6            Soccer         187  Cristiano Ronaldo
# 7            Soccer         185    Zinedine Zidane
# 8          Swimming         200           Sun Yang
# 9          Swimming         196         Ian Thorpe
# 10           Tennis         188     Novak Djokovic
# 11           Tennis         185      Roger Federer
# 12  Track and Field         195         Usain Bolt
# 13  Track and Field         188         Carl Lewis

# %%
#Question num 4
new_rows = pd.DataFrame({ 'Country': ['Canada', 'USA'], 'Sport Type': ['Hockey', 'Skiing'],
'Athlete Name': ['Wayne Gretzky', 'Lindsey Vonn'], 'Height(cm)': [183, 172],
'Weight(kg)': [84, 68], 'Wins': [3, 4], 'Olympic Date': ['01/02/2002', '12/02/2010'] })

df_concat = pd.concat([df_copy1, new_rows], axis=0)
df_concat
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...
